# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn import datasets, tree, linear_model

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\cj\\Python CJ_Practice'

# %%
featuresData = pd.read_csv("../python_CJ_ST_Copy/dataset/feature_regression_example.csv")

# %%
featuresData.corr()
# Out:
#              YEARWEEK      YEAR      WEEK       QTY     HCLUS  PRO_PERCENT
# YEARWEEK     1.000000  0.961051  0.213022  0.037392 -0.030681     0.300320
# YEAR         0.961051  1.000000 -0.065302 -0.048803  0.067443     0.208435
# WEEK         0.213022 -0.065302  1.000000  0.307541 -0.349205     0.347462
# QTY          0.037392 -0.048803  0.307541  1.000000 -0.544920     0.712772
# HCLUS       -0.030681  0.067443 -0.349205 -0.544920  1.000000    -0.552991
# PRO_PERCENT  0.300320  0.208435  0.347462  0.712772 -0.552991     1.000000

# %%
featuresData.head(5)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0  1225       Y      1         Y     0.209442
# 1   968       N      4         Y     0.209442
# 2  1209       N      4         Y     0.208155
# 3  1810       Y      2         Y     0.208155
# 4  1773       N      4         Y     0.208155

# %%
featuresData.dtypes
# Out:
# REGIONID         object
# PRODUCTGROUP     object
# PRODUCT          object
# ITEM             object
# YEARWEEK          int64
# YEAR              int64
# WEEK              int64
# QTY               int64
# HOLIDAY          object
# HCLUS             int64
# PROMOTION        object
# PRO_PERCENT     float64
# dtype: object

# %%
featuresData[['YEARWEEK', 'QTY', 'PRO_PERCENT']]= featuresData[['YEARWEEK', 'QTY', 'PRO_PERCENT']].astype('float64')

# %%
def codeConversion(df):
    if df == "Y":
        return 1
    else:
        return 0

# %%
featuresData ['PROMOTIONCODE'] = featuresData['PROMOTION'].apply(codeConversion)

# %%
featuresData.dtypes
# Out:
# REGIONID          object
# PRODUCTGROUP      object
# PRODUCT           object
# ITEM              object
# YEARWEEK         float64
# YEAR               int64
# WEEK               int64
# QTY              float64
# HOLIDAY           object
# HCLUS              int64
# PROMOTION         object
# PRO_PERCENT      float64
# PROMOTIONCODE      int64
# dtype: object

# %%
featuresData.head(5)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201501.0  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201502.0  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201503.0  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201504.0  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201505.0  2015     5
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE
# 0  1225.0       Y      1         Y     0.209442              1
# 1   968.0       N      4         Y     0.209442              1
# 2  1209.0       N      4         Y     0.208155              1
# 3  1810.0       Y      2         Y     0.208155              1
# 4  1773.0       N      4         Y     0.208155              1

# %%
featuresData ['HOLIDAYCODE'] = featuresData['HOLIDAY'].apply(codeConversion)

# %%
featuresData.head(5)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201501.0  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201502.0  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201503.0  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201504.0  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201505.0  2015     5
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE
# 0  1225.0       Y      1         Y     0.209442              1            1
# 1   968.0       N      4         Y     0.209442              1            0
# 2  1209.0       N      4         Y     0.208155              1            0
# 3  1810.0       Y      2         Y     0.208155              1            1
# 4  1773.0       N      4         Y     0.208155              1            0

# %%
predictStd = 201630

# %%
trainingData = featuresData.query('YEARWEEK <= @predictStd')

# %%
trainingData.head(5)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201501.0  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201502.0  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201503.0  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201504.0  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201505.0  2015     5
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE
# 0  1225.0       Y      1         Y     0.209442              1            1
# 1   968.0       N      4         Y     0.209442              1            0
# 2  1209.0       N      4         Y     0.208155              1            0
# 3  1810.0       Y      2         Y     0.208155              1            1
# 4  1773.0       N      4         Y     0.208155              1            0

# %%
testData = featuresData.query('YEARWEEK < @predictStd')

# %%
testData = featuresData.query('YEARWEEK > @predictStd')

# %%
testData.head(5)
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 83  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201631.0  2016    31
# 84  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201632.0  2016    32
# 85  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201633.0  2016    33
# 86  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201634.0  2016    34
# 87  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201635.0  2016    35
#
#        QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE
# 83  1522.0       N      4         Y     0.280258              1            0
# 84  2100.0       N      4         Y     0.280258              1            0
# 85    43.0       N      4         N     0.000000              0            0
# 86  1700.0       Y      1         Y     0.308584              1            1
# 87  1514.0       Y      1         Y     0.308584              1            1

# %%
trainingData_feature = trainingData[['WEEK', 'PRO_PERCENT', 'HOLIDAYCODE']]

# %%
trainingData_label = trainingData[['QTY']]

# %%
testData_feature = testData[['WEEK', 'PRO_PERCENT', 'HOLIDAYCODE']]

# %%
testData_label = testData[['QTY']]

# %%
model_method = tree.DecisionTreeClassifier()

# %%
model = model_method.fit(trainingData_feature, trainingData_label)

# %%
model
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predict = model.predict(testData_feature)

# %%
predict
# Out:
# array([2240., 2240.,  147., 1318., 1318., 1318., 1318., 1318., 2240.,
#        2240., 2671., 2240.,  230., 1454., 1454., 2033., 2033., 3691.,
#        1758., 1758., 1758., 1758.,  350.,  301.])

# %%
testData_label.head(5)
# Out:
#        QTY
# 83  1522.0
# 84  2100.0
# 85    43.0
# 86  1700.0
# 87  1514.0

# %%
type(predict)
# Out:
# numpy.ndarray

# %%
predictData = pd.DataFrame(predict)

# %%
predictData
# Out:
#          0
# 0   2240.0
# 1   2240.0
# 2    147.0
# 3   1318.0
# 4   1318.0
# 5   1318.0
# 6   1318.0
# 7   1318.0
# 8   2240.0
# 9   2240.0
# 10  2671.0
# 11  2240.0
# 12   230.0
# 13  1454.0
# 14  1454.0
# 15  2033.0
# 16  2033.0
# 17  3691.0
# 18  1758.0
# 19  1758.0
# 20  1758.0
# 21  1758.0
# 22   350.0
# 23   301.0

# %%
predictData.columns = ["PREDICT"]

# %%
predict
# Out:
# array([2240., 2240.,  147., 1318., 1318., 1318., 1318., 1318., 2240.,
#        2240., 2671., 2240.,  230., 1454., 1454., 2033., 2033., 3691.,
#        1758., 1758., 1758., 1758.,  350.,  301.])

# %%
predictData
# Out:
#     PREDICT
# 0    2240.0
# 1    2240.0
# 2     147.0
# 3    1318.0
# 4    1318.0
# 5    1318.0
# 6    1318.0
# 7    1318.0
# 8    2240.0
# 9    2240.0
# 10   2671.0
# 11   2240.0
# 12    230.0
# 13   1454.0
# 14   1454.0
# 15   2033.0
# 16   2033.0
# 17   3691.0
# 18   1758.0
# 19   1758.0
# 20   1758.0
# 21   1758.0
# 22    350.0
# 23    301.0

# %%
testData.reset_index(drop=True, inplace=True)

# %%
finalDf = pd.concat([testData, predictData], axis=1)

# %%
fianlDf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-85003885bf90> in <module>()
# ----> 1 fianlDf
#
# NameError: name 'fianlDf' is not defined

# %%
finalDf
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201631.0  2016    31
# 1   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201632.0  2016    32
# 2   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201633.0  2016    33
# 3   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201634.0  2016    34
# 4   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201635.0  2016    35
# 5   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201636.0  2016    36
# 6   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201637.0  2016    37
# 7   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201638.0  2016    38
# 8   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201639.0  2016    39
# 9   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201640.0  2016    40
# 10  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201641.0  2016    41
# 11  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201642.0  2016    42
# 12  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201643.0  2016    43
# 13  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201644.0  2016    44
# 14  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201645.0  2016    45
# 15  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201646.0  2016    46
# 16  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201647.0  2016    47
# 17  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201648.0  2016    48
# 18  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201649.0  2016    49
# 19  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201650.0  2016    50
# 20  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201651.0  2016    51
# 21  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201652.0  2016    52
# 22  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201710.0  2017    10
# 23  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201714.0  2017    14
#
#        QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE  \
# 0   1522.0       N      4         Y     0.280258              1            0
# 1   2100.0       N      4         Y     0.280258              1            0
# 2     43.0       N      4         N     0.000000              0            0
# 3   1700.0       Y      1         Y     0.308584              1            1
# 4   1514.0       Y      1         Y     0.308584              1            1
# 5   1501.0       Y      1         Y     0.308584              1            1
# 6   1491.0       N      4         Y     0.308584              1            0
# 7    806.0       N      4         Y     0.308584              1            0
# 8   2111.0       N      4         Y     0.280258              1            0
# 9   2400.0       N      4         Y     0.280258              1            0
# 10  2010.0       Y      2         Y     0.280258              1            1
# 11  1900.0       N      4         Y     0.280258              1            0
# 12   141.0       N      4         N     0.000000              0            0
# 13  1615.0       Y      0         Y     0.421888              1            1
# 14  1574.0       Y      0         Y     0.421888              1            1
# 15  1800.0       Y      0         Y     0.421888              1            1
# 16  2600.0       Y      0         Y     0.421888              1            1
# 17  2412.0       Y      0         Y     0.421888              1            1
# 18  1955.0       N      4         Y     0.421888              1            0
# 19  1800.0       N      4         Y     0.352361              1            0
# 20  1173.0       N      4         Y     0.352361              1            0
# 21   332.0       Y      1         Y     0.352361              1            1
# 22    14.0       N      4         N     0.000000              0            0
# 23     5.0       N      4         N     0.000000              0            0
#
#     PREDICT
# 0    2240.0
# 1    2240.0
# 2     147.0
# 3    1318.0
# 4    1318.0
# 5    1318.0
# 6    1318.0
# 7    1318.0
# 8    2240.0
# 9    2240.0
# 10   2671.0
# 11   2240.0
# 12    230.0
# 13   1454.0
# 14   1454.0
# 15   2033.0
# 16   2033.0
# 17   3691.0
# 18   1758.0
# 19   1758.0
# 20   1758.0
# 21   1758.0
# 22    350.0
# 23    301.0

# %%
finalDf.head(5)
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201631.0  2016    31
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201632.0  2016    32
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201633.0  2016    33
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201634.0  2016    34
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115  201635.0  2016    35
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  PROMOTIONCODE  HOLIDAYCODE  \
# 0  1522.0       N      4         Y     0.280258              1            0
# 1  2100.0       N      4         Y     0.280258              1            0
# 2    43.0       N      4         N     0.000000              0            0
# 3  1700.0       Y      1         Y     0.308584              1            1
# 4  1514.0       Y      1         Y     0.308584              1            1
#
#    PREDICT
# 0   2240.0
# 1   2240.0
# 2    147.0
# 3   1318.0
# 4   1318.0

# %%
mean_squared_error(finalDf['QTY'], finalDf['PREDICT'])
# Out:
# 263635.4583333333

# %%
mean_absolute_error(finalDf['QTY'], finalDf['PREDICT'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-82d1d9ce493d> in <module>()
# ----> 1 mean_absolute_error(finalDf['QTY'], finalDf['PREDICT'])
#
# TypeError: 'tuple' object is not callable
